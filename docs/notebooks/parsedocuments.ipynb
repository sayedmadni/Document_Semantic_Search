# %%
print("hello world")
# Out:
# hello world

# %%
from docling.document_converter import DocumentConverter
converter = DocumentConverter()

# %%
source = "https://arxiv.org/pdf/2304.03442"
result = converter.convert(source)
# Out:
# 2025-10-06 09:45:00,288 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-06 09:45:00,306 - INFO - Going to convert document batch...
# 2025-10-06 09:45:00,306 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-10-06 09:45:00,311 - INFO - Loading plugin 'docling_defaults'
# 2025-10-06 09:45:00,313 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-10-06 09:45:00,322 - INFO - Loading plugin 'docling_defaults'
# 2025-10-06 09:45:00,326 - INFO - Registered ocr engines: ['easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-10-06 09:45:00,529 - INFO - Accelerator device: 'cuda:0'
# 2025-10-06 09:45:00,534 - WARNING - Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# 2025-10-06 09:45:01,976 - INFO - Download complete
# ...

# %%
import json

result_dict = result.document.export_to_dict()
print(json.dumps(result_dict, indent=2))
# Out:
# {
#   "schema_name": "DoclingDocument",
#   "version": "1.7.0",
#   "name": "2304.03442v2",
#   "origin": {
#     "mimetype": "application/pdf",
#     "binary_hash": 15763741383652254009,
#     "filename": "2304.03442v2.pdf"
#   },
#   "furniture": {
#     "self_ref": "#/furniture",
#     "children": [],
#     "content_layer": "furniture",
#     "name": "_root_",
#     "label": "unspecified"
#   },
#   "body": {
#     "self_ref": "#/body",
#     "children": [
#       {
#         "$ref": "#/texts/0"
#       },
#       {
#         "$ref": "#/texts/1"
#       },
#       {
#         "$ref": "#/texts/2"
#       },
#       {
#         "$ref": "#/texts/3"
#       },
#       {
#         "$ref": "#/texts/4"
#       },
#       {
#         "$ref": "#/texts/5"
#       },
#       {
#         "$ref": "#/texts/6"
#       },
#       {
#         "$ref": "#/texts/7"
#       },
#       {
#         "$ref": "#/pictures/0"
#       },
#       {
#         "$ref": "#/texts/57"
#       },
#       {
# ...

# %%
with open(f"docs/notebooks/parsed_output.jsonl", "w", encoding="utf-8") as f:
    for page in parsed.get("content", []):
        f.write(json.dumps(page) + "\n")
